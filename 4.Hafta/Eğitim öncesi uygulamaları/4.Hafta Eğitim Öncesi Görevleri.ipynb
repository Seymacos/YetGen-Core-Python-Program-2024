# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
#Sözlük kullanılarak telefon rehberi yazılmıştır.
telefonRehberi = {"Ahmet" : "0532 678 13 19","Şeyma" : "0555 555 55 55", "Selin" : "0505 505 50 55",  "Leyla" : "0509 509 09 09" }

#Kullanıcıdan bakılmak istenen kişinin adını al.
ad = input("Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: ")

#İstenilen kişinin telefon numarasını yazdır.
if ad in telefonRehberi:
    print(f"{ad} isimli kişinin numarası şu şekildedir: {telefonRehberi[ad]}")
else:
    print("Bu ada sahip kimse yoktur.")
# Out:
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
#Sözlük kullanılarak çalışanların bilgileri yazılmıştır.
sirketCalisanlari = {
    "Mehmet Yağız": ["Adana", "40", "Direktör"],
    "Şeyma Coştur": ["Manisa", "23", "Mühendis"],
    "Selin Kavak": ["Rize", "20", "Mimar"],
    "Ali Ferah": ["Antalya", "52", "Yönetici"],
}

#Kullanıcıdan bakılmak istenen kişinin adını al.
ad = input("Lütfen bilgilerini öğrenmek istediğiniz kişinin adını girin: ")
print(ad)

#İstenilen kişinin bilgilerini getir.
if ad in sirketCalisanlari:

    calisan = sirketCalisanlari[ad]
    print(f"{ad} =  Memleket:{calisan[0]}  Yaş:{calisan[1]}  Görev:{calisan[2]}")

else:
    print("Bu ada sahip bir çalışan yoktur.")
# Out:
# Mehmet Yağız
# Mehmet Yağız =  Memleket:Adana  Yaş:40  Görev:Direktör

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
#Sözlük kullanılarak öğrenci not sözlüğü oluşturuldu.
ogrenciNotlari = {
    "Mehmet": ["72", "66", "48"],
    "Şeyma": ["89", "56", "92"],
    "Selin": ["12", "45", "52"],
}

#Kullanıcıdan bakılmak istenen öğrencinin adını al.
ad = input("Lütfen notlarını görmek istediğiniz öğrencinin adını girin: ")

#İstenilen kişinin bilgilerini getir.
if ad in ogrenciNotlari:

    notlar = ogrenciNotlari[ad]
    notlar = [int(notlar) for notlar in notlar]

    notOrtalamasi = sum(notlar) / len(notlar)


    print(f"{ad} isimli öğrencinin   1. Sınav Notu: {notlar[0]}\n"
          f"                           2. Sınav Notu: {notlar[1]}\n"
          f"                           3. Sınav Notu: {notlar[2]}\n"
          f"Not Ortalaması: {notOrtalamasi:.1f}")                                                          

else:
    print("Bu ada sahip bir öğrenci yoktur.")
# Out:
# Mehmet isimli öğrencinin   1. Sınav Notu: 72
#                            2. Sınav Notu: 66
#                            3. Sınav Notu: 48
# Not Ortalaması: 62.0

# %% [markdown]
# # Problem 4

# %%
# 1-  "Bmw, Mercedes, Opel, Mazda" elemanlarına sahip bir liste oluşturunuz.
araba = ["Bmw", "Mercedes", "Opel", "Mazda"]
print("araba:", araba)

# 2-  Liste Kaç elemanlıdır ?
arabaLen = len(araba)
print("Liste Kaç elemanlıdır ?:", arabaLen)

# 3-  Listenin ilk ve son elemanı nedir ?
ilkEleman = araba[0]
sonEleman = araba[-1]
print("İlk Eleman:", ilkEleman)
print("Son leman:", sonEleman)

# 4-  Mazda değerini Toyota ile değiştirin.
araba[3] = "Toyota"

# 5-  Listenin -2 indeksindeki değer nedir ?
indeksEksi2 = araba[-2]
print("Listenin -2 indeksindeki değer nedir ?:", indeksEksi2)

# 6-  Listenin ilk 3 elemanını alın.
ilk3eleman = araba[:3]
print("Listenin ilk 3 elemanını alın.:", ilk3eleman)

# 7-  Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.
araba[-2:] = ["Toyota", "Renault"]
print("araba:", araba)

# 8-  Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.
araba.extend(["Audi", "Nissan"])
print("araba:", araba)

# 9- Listenin son elemanını silin.
del araba[-1]
print("araba:", araba)

# 10- Liste elemanlarını tersten yazdırınız.
tersAraba = araba[::1]
print("Liste elemanlarını tersten yazdırınız.:", tersAraba)

# 11- Aşağıdaki verileri bir liste içinde saklayınız. 

      # studentA: Yiğit Bilgi 2010, (70,60,70)
      # studentB: Sena Turan  1999, (80,80,70)
      # studentC: Ahmet Turan 1998, (80,70,90) 

students = [
    {"ad": "Yiğit Bilgi", "yıl": 2010, "not": (70,60,70)},
    {"ad": "Sena Turan", "yıl": 1999, "not": (80,80,70)},
    {"ad": "Ahmet Turan", "yıl": 1998, "not": (80,70,90)}
]

# 12- Liste elemanlarını ekrana yazdırınız.
print("Students:", students)

names = ['Ali','Yağmur','Hakan','Deniz']
years = [1998, 2000, 1998, 1987]

# 13-  "Cenk" ismini listenin sonuna ekleyiniz.
names.append("Cenk")
print("names:", names)

# 14-  "Sena" değerini listenin başına ekleyiniz.
names.insert(0, "Sena")
print("names:", names)

# 15-  "Deniz" ismini listeden siliniz.
if "Deniz" in names:
    names.remove("Deniz")

print("names:", names)

# 16-  "Ali" listenin bir elemanı mıdır ?
aliEleman = "Ali" in araba

# 17-  Liste elemanlarını ters çevirin.
names.reverse()

# 18-  Liste elemanlarını alfabetik olarak sıralayınız.
names.sort()


# 19-  years listesini rakamsal büyüklüğe göre sıralayınız.
years.sort()


# 20-  str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.
str = "Chevrolet,Dacia"
strList = str.split(",")

# 21- years dizisinde kaç tane 1998 değeri vardır ?
say1998 = years.count(1998)

# 22- years dizisinin tüm elemanlarını siliniz.
years.clear()


# 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.
markaList = []
for i in range(3):
    marka= input(f"{i+1}. marka: ")
    markaList.append(marka)
print("Kullanıcıdan Alınan Marka Bilgileri:", markaList)
# Out:
# araba: ['Bmw', 'Mercedes', 'Opel', 'Mazda']
# Liste Kaç elemanlıdır ?: 4
# İlk Eleman: Bmw
# Son leman: Mazda
# Listenin -2 indeksindeki değer nedir ?: Opel
# Listenin ilk 3 elemanını alın.: ['Bmw', 'Mercedes', 'Opel']
# araba: ['Bmw', 'Mercedes', 'Toyota', 'Renault']
# araba: ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi', 'Nissan']
# araba: ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi']
# Liste elemanlarını tersten yazdırınız.: ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi']
# Students: [{'ad': 'Yiğit Bilgi', 'yıl': 2010, 'not': (70, 60, 70)}, {'ad': 'Sena Turan', 'yıl': 1999, 'not': (80, 80, 70)}, {'ad': 'Ahmet Turan', 'yıl': 1998, 'not': (80, 70, 90)}]
# names: ['Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# names: ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# names: ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Cenk']
# Kullanıcıdan Alınan Marka Bilgileri: ['a', 'b', 'c']
