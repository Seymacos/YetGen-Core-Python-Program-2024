# %% [markdown]
# # Problem 1
# Kullanıcıdan bir sayı alınız. Sayı 0'dan büyükse pozitif , 0'dan küçükse negatif sıfıra eşitse sıfır yazdırınız.

# %%
#Kullanicıdan sayı değerini al.
sayi = int(input(print("Bir sayı giriniz.")))

#Koşullara uygun istedilenleri yazdır.
if(sayi>0):
    print("POZİTİF")
elif(sayi==0):
    print("SIFIR")
else:
    print("NEGATİF")
# Out:
# Bir sayı giriniz.
# NEGATİF

# %% [markdown]
#  # Problem 2
# Kullanıcıdan aldığınız bir sayının mükemmel olup olmadığını bulmaya çalışın.
# Bir sayının kendi hariç bölenlerinin toplamı kendine eşitse bu sayıya "mükemmel sayı" denir. Örnek olarak, 6 mükemmel bir sayıdır. (1 + 2 + 3 = 6)

# %%
#Kullanicıdan sayı değerini al.
sayi = int(input(print("Bir sayı giriniz.")))
#Toplam adında değişken oluştur 
toplam=0
#Range fonksiyonu ile girilen sayının bölünüp bölünmediğini kontrol et.
for i in range(1,sayi):
    if (sayi%i==0):
        toplam=toplam+i
#Koşullara uygun istedilenleri yazdır.
if  toplam==sayi:
    print(f"{sayi} mükemmel bir sayıdır.")
else:
    print(f"{sayi} mükemmel sayı değildir.")
# Out:
# Bir sayı giriniz.
# 6 mükemmel bir sayıdır.

# %% [markdown]
#  # Problem 3
# Kullanıcıdan aldığınız bir sayının "Armstrong" sayısı olup olmadığını bulmaya çalışın.
# Örnek olarak, Bir sayı eğer 4 basamaklı ise ve oluşturan rakamlardan herbirinin 4. kuvvetinin toplamı( 3 basamaklı sayılar için 3.kuvveti ) o sayıya eşitse bu sayıya "Armstrong" sayısı denir.
#
# Örnek olarak : 1634 = 1^4 + 6^4 + 3^4 + 4^4

# %%
#Kullanicıdan sayı değerini al.
sayi = int(input(print("Bir sayı giriniz.")))

#Basamak sayısını hesaplamak için stringe dönüştür
sayi1 = str(sayi)
basamakSayisi= len(sayi1)

toplam=0
for armstrong in sayi1:
    toplam = toplam + (int(armstrong)**basamakSayisi)

#Armstrong sayısı olup olmadığını kontrol et
if toplam == sayi:
    print(f"{sayi} Armstrong sayısıdır.")
else:
    print(f"{sayi} Armstrong sayısı değildir.")
# Out:
# Bir sayı giriniz.
# 1634 Armstrong sayısıdır.

# %% [markdown]
# # Problem 4
# YetGen Core Python mezunu bir öğretmenimiz öğrencilerine 1'den 10'a kadar sayılarla çarpım tablosunu öğretirken Python'dan destek almak istiyor. Bu konuda öğretmenimize yardımcı olmak ister misin?
#
# İpucu: İç içe 2 tane for döngüsü kullanın.
#
# Aynı zamanda sayıları range() fonksiyonunu kullanarak elde edin.

# %%
#1'den 10'a sayılar
for i in range (1,11):
    #0'dan 10'a kadar sayılar
    for j in range (0,11):
        #Çarpma işleminin yapılması
        print(f"{i}x{j}={i*j}")
    print("******")
# Out:
# 1x0=0
# 1x1=1
# 1x2=2
# 1x3=3
# 1x4=4
# 1x5=5
# 1x6=6
# 1x7=7
# 1x8=8
# 1x9=9
# 1x10=10
# ******
# 2x0=0
# 2x1=2
# 2x2=4
# 2x3=6
# 2x4=8
# 2x5=10
# 2x6=12
# 2x7=14
# 2x8=16
# 2x9=18
# 2x10=20
# ******
# 3x0=0
# 3x1=3
# 3x2=6
# 3x3=9
# 3x4=12
# 3x5=15
# 3x6=18
# 3x7=21
# 3x8=24
# 3x9=27
# 3x10=30
# ******
# 4x0=0
# 4x1=4
# 4x2=8
# 4x3=12
# 4x4=16
# 4x5=20
# 4x6=24
# 4x7=28
# 4x8=32
# 4x9=36
# 4x10=40
# ******
# 5x0=0
# 5x1=5
# 5x2=10
# 5x3=15
# 5x4=20
# 5x5=25
# 5x6=30
# 5x7=35
# 5x8=40
# 5x9=45
# 5x10=50
# ******
# 6x0=0
# 6x1=6
# 6x2=12
# 6x3=18
# 6x4=24
# 6x5=30
# 6x6=36
# 6x7=42
# 6x8=48
# 6x9=54
# 6x10=60
# ******
# 7x0=0
# 7x1=7
# 7x2=14
# 7x3=21
# 7x4=28
# 7x5=35
# 7x6=42
# 7x7=49
# 7x8=56
# 7x9=63
# 7x10=70
# ******
# 8x0=0
# 8x1=8
# 8x2=16
# 8x3=24
# 8x4=32
# 8x5=40
# 8x6=48
# 8x7=56
# 8x8=64
# 8x9=72
# 8x10=80
# ******
# 9x0=0
# 9x1=9
# 9x2=18
# 9x3=27
# 9x4=36
# 9x5=45
# 9x6=54
# 9x7=63
# 9x8=72
# 9x9=81
# 9x10=90
# ******
# 10x0=0
# 10x1=10
# 10x2=20
# 10x3=30
# 10x4=40
# 10x5=50
# 10x6=60
# 10x7=70
# 10x8=80
# 10x9=90
# 10x10=100
# ******

# %% [markdown]
# # Problem 5
# Markete giren bir YetGen'li sıra beklememek için hızlı kasaya gider. Hızlı kasanın çalışma mantığı şu şekildedir:
# - Kullanıcının aldığı her ürünün fiyatını tek tek girmesi gerekir.
# - Kullanıcı kasadan çıkmak isterse q tuşuna basmalıdır.
# - Kasa girilen fiyatları son fiyat isimli değişkene ekler.
# - Değişkeni ekrana bastırır.
#
# İpucu: while döngüsünü sonsuz koşulla başlatın ve kullanıcı q'ya basarsa döngüyü break ile sonlandırın.

# %%
#Toplam adında değişken oluştur 
toplamTutar = 0
#Kullanıcıdan tutarı al.
tutar = (input(print("Ürünün fiyatını giriniz (Çıkmak için q tuşuna basmanız gerekmektedir).")))
#q tuşuna basana kadar girş almaya devam et.
while tutar!="q":
    toplamTutar=toplamTutar+float(tutar)
    tutar =  (input(print("Ürünün fiyatını giriniz (Çıkmak için q tuşuna basmanız gerekmektedir).")))
#Sonucu yazdır.
print(f"Toplam tutar: {toplamTutar}")
# Out:
# Ürünün fiyatını giriniz (Çıkmak için q tuşuna basmanız gerekmektedir).
# Ürünün fiyatını giriniz (Çıkmak için q tuşuna basmanız gerekmektedir).
# Toplam tutar: 4.0

# %% [markdown]
# # Problem 6
# 1'den 100'e kadar olan sayılardan sadece 3'e bölünen sayıları ekrana bastırın. Bu işlemi continue ile yapmaya çalışın.

# %%
#1'den 100 dahil tüm sayıları kontrol et.
for i in range (1,100):
    #3' bölünmüyorsa continue ile tekrar döngüye dön
    if i%3!=0:
       continue
    #Bölünüyorsa ekrana yazdır.
    else:
        print(i)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99

# %% [markdown]
# # Problem 7
# Bir YetGen Core Python mezunu MEF Üniversitesi'nde Bilgisayar Bilimleri Doktora programının mülakatına girmeye hak kazanıyor. Mülakata hazırlanırken internetten soru araştırıyor. Karşısına çıkan ünlü FizzBuzz sorusuna benzer YetGen sorusunda kendisini yeterince hazır hissetmiyor. Bu soruyu çözmesine destek olmak ister misin?
#
# Soru aşağıdaki gibidir:
#
# 1’den 100’e kadar sayıları yazdırıyoruz. Ancak eğer sayı 3’e bölünüyor ise Yet, sayı 5’e bölünüyorsa Gen, hem 3’e hem 5’e bölünüyorsa YetGen yazdırıyoruz.

# %%
#1'den 100 dahil tüm sayıları kontrol et.
for i in range (1,100):
    #3' e ve 5'e bölünüyorsa
    if i%3==0 and i%5==0:
        print(f"{i}  Yetgen")
    #3'e bölünüyorsa
    elif i%3==0:
       print(f"{i}  Yet")
    #5'e bölünüyorsa
    elif i%5==0:
        print(f"{i}  Gen")
# Out:
# 3  Yet
# 5  Gen
# 6  Yet
# 9  Yet
# 10  Gen
# 12  Yet
# 15  Yetgen
# 18  Yet
# 20  Gen
# 21  Yet
# 24  Yet
# 25  Gen
# 27  Yet
# 30  Yetgen
# 33  Yet
# 35  Gen
# 36  Yet
# 39  Yet
# 40  Gen
# 42  Yet
# 45  Yetgen
# 48  Yet
# 50  Gen
# 51  Yet
# 54  Yet
# 55  Gen
# 57  Yet
# 60  Yetgen
# 63  Yet
# 65  Gen
# 66  Yet
# 69  Yet
# 70  Gen
# 72  Yet
# 75  Yetgen
# 78  Yet
# 80  Gen
# 81  Yet
# 84  Yet
# 85  Gen
# 87  Yet
# 90  Yetgen
# 93  Yet
# 95  Gen
# 96  Yet
# 99  Yet
