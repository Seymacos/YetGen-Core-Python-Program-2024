# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
import datetime

# VKI hesaplama fonksiyonu
def vkiHesapla(kilo, boy):
    return round(kilo / (boy * boy))

# VKI'ye göre sınıflandırma
def vkiSiniflandirma(vki):
    if vki < 18.5:
        return "Zayıf"
    elif 18.5 <= vki < 24.9:
        return "Normal kilolu"
    elif 25 <= vki < 29.9:
        return "Fazla kilolu"
    elif 30 <= vki < 39.9:
        return "Obez"
    else:
        return "İleri derecede obez (morbid obez)"

# Tarih formatını kontrol etme fonksiyonu
def tarihKontrol(tarih):
    try:
        datetime.datetime.strptime(tarih, "%d.%m.%Y")
        return True
    except ValueError:
        return False


# Kullanıcıdan veri alma ve VKI hesaplama
def veriAlmaVeIsleme(girisSayisi):
    data = []
    for i in range(girisSayisi):
        isim = input("İsim giriniz: ")
        soyisim = input("Soyisim giriniz: ")
        yas = int(input("Yaşını giriniz: "))
        boy = float(input("Boyunu giriniz (metre cinsinden): "))
        kilo = float(input("Kilosunu giriniz: "))
        tarih = input("Tarihi giriniz (gün.ay.yıl: ")
        vki = vkiHesapla(kilo, boy)
        sinif = vkiSiniflandirma(vki)
        
        data.append({
            "isim": isim,
            "soyisim": soyisim,
            "yas": yas,
            "boy": boy,
            "kilo": kilo,
            "vki": vki,
            "sinif": sinif,
            "tarih": tarih
        })
    
        # Dosyaya yazma (append mode, mevcut verileri silmeden)
    with open('vki.txt', 'a', encoding='utf-8') as file:
        # Dosya başlık yazısı kontrolü (dosya boşsa başlık yazdır)
        file.seek(0, 2)  # Dosya sonuna git
        if file.tell() == 0:  # Eğer dosya boşsa başlık yazdır
            file.write(f"{'İsim':<20} {'Soyisim':<20} {'Yaş':<5} {'Boy (m)':<10} {'Kilo (kg)':<10} {'VKI':<10} {'Sınıf':<20} {'Tarih':<12}\n")
        for entry in data:
            file.write(f"{entry['isim']:<20} {entry['soyisim']:<20} {entry['yas']:<5} {entry['boy']:<10.2f} {entry['kilo']:<10.2f} {entry['vki']:<10.2f} {entry['sinif']:<20} {entry['tarih']:<12}\n")
    
    print("Dosyaya kaydedildi.")


girisSayisi = int(input("Kaç giriş yapacaksınız? "))
veriAlmaVeIsleme(girisSayisi)
# Out:
# Dosyaya kaydedildi.

# %%
import datetime

# VKI hesaplama fonksiyonu
def vkiHesapla(kilo, boy):
    if boy <= 0:
        return 0  # Boyun sıfır veya negatif olması durumunda VKI hesaplaması yapılmaz
    return kilo / (boy * boy)

# VKI'ye göre sınıflandırma
def vkiSiniflandirma(vki):
    if vki < 18.5:
        return "Zayıf"
    elif 18.5 <= vki < 24.9:
        return "Normal kilolu"
    elif 25 <= vki < 29.9:
        return "Fazla kilolu"
    elif 30 <= vki < 39.9:
        return "Obez"
    else:
        return "İleri derecede obez (morbid obez)"

# Tarih formatını kontrol etme fonksiyonu
def tarihKontrol(tarih):
    try:
        datetime.datetime.strptime(tarih, "%d-%m-%Y")
        return True
    except ValueError:
        return False

# Kullanıcıdan veri alma ve VKI hesaplama
def veriAlmaVeIsleme(girisSayisi):
    data = []
    for _ in range(girisSayisi):
        isim = input("İsim giriniz: ")
        soyisim = input("Soyisim giriniz: ")
        yas = int(input("Yaşını giriniz: "))
        boy = float(input("Boyunu giriniz (metre cinsinden, örn: 1.75): "))
        kilo = float(input("Kilosunu giriniz: "))
        
        tarih = input("Tarihi giriniz (gün-ay-yıl formatında, örn: 19-07-2024): ")
        while not tarihKontrol(tarih):
            print("Geçersiz tarih formatı. Lütfen tekrar deneyiniz.")
            tarih = input("Tarihi giriniz (gün-ay-yıl formatında, örn: 19-07-2024): ")
        
        vki = vkiHesapla(kilo, boy)
        sinif = vkiSiniflandirma(vki)
        
        data.append({
            "isim": isim,
            "soyisim": soyisim,
            "yas": yas,
            "boy": boy,
            "kilo": kilo,
            "vki": vki,
            "sinif": sinif,
            "tarih": tarih
        })

    # Dosyaya yazma (append mode, mevcut verileri silmeden)
    with open('vki.txt', 'a', encoding='utf-8') as file:
        file.seek(0, 2)  # Dosya sonuna git
        if file.tell() == 0:  # Eğer dosya boşsa başlık yazdır
            file.write(f"{'İsim':<20} {'Soyisim':<20} {'Yaş':<5} {'Boy (m)':<10} {'Kilo (kg)':<10} {'VKI':<10} {'Sınıf':<20} {'Tarih':<12}\n")
        for entry in data:
            file.write(f"{entry['isim']:<20} {entry['soyisim']:<20} {entry['yas']:<5} {entry['boy']:<10.2f} {entry['kilo']:<10.2f} {entry['vki']:<10.2f} {entry['sinif']:<20} {entry['tarih']:<12}\n")

    # Yazdırma işlemi (ekranda tablo şeklinde)
    print(f"{'İsim':<20} {'Soyisim':<20} {'Yaş':<5} {'Boy (m)':<10} {'Kilo (kg)':<10} {'VKI':<10} {'Sınıf':<20} {'Tarih':<12}")
    for entry in data:
        print(f"{entry['isim']:<20} {entry['soyisim']:<20} {entry['yas']:<5} {entry['boy']:<10.2f} {entry['kilo']:<10.2f} {entry['vki']:<10.2f} {entry['sinif']:<20} {entry['tarih']:<12}")

# Ana program
girisSayisi = int(input("Kaç giriş yapacaksınız? "))
veriAlmaVeIsleme(girisSayisi)
# Out:
# Geçersiz tarih formatı. Lütfen tekrar deneyiniz.
# Geçersiz tarih formatı. Lütfen tekrar deneyiniz.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 74
#      72 # Ana program
#      73 girisSayisi = int(input("Kaç giriş yapacaksınız? "))
# ---> 74 veriAlmaVeIsleme(girisSayisi)
#
# Cell In[17], line 43, in veriAlmaVeIsleme(girisSayisi)
#      41 while not tarihKontrol(tarih):
#      42     print("Geçersiz tarih formatı. Lütfen tekrar deneyiniz.")
# ---> 43     tarih = input("Tarihi giriniz (gün-ay-yıl formatında, örn: 19-07-2024): ")
#      45 vki = vkiHesapla(kilo, boy)
#      46 sinif = vkiSiniflandirma(vki)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
